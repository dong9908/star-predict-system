# %%
# 다른 폴더에 git clone https://codeberg.org/astronexus/hyg.git 을 하고 테스트를 진행.
# 테스트 완료 시, DB에 별자리 데이터를 가지고 계산할 수 있게 만들면 됨.
# 해당 파일은 위의 git clone 이후 폴더 안에 집어넣은 기준으로 짜여진 코드임.

import pandas as pd

df = pd.read_csv("data/hyg/current/hyg_v44.csv.gz")

print(df.columns.tolist())
print(df.head())

# %%
# proper, ra, dec가 모두 존재하는 별만 선택
star = df.dropna(subset=["proper", "ra", "dec"]).iloc[0]

print("별 이름:", star["proper"])
print("적경(RA):", star["ra"])
print("적위(Dec):", star["dec"])
print(df["con"].dropna().unique())
# Out:
# 별 이름: Sol
# 적경(RA): 0.0
# 적위(Dec): 0.0
# ['Psc' 'Cet' 'And' 'Phe' 'Peg' 'Scl' 'Cas' 'Oct' 'Cep' 'Tuc' 'Hyi' 'UMi'
#  'Eri' 'Per' 'Tri' 'For' 'Ari' 'Hor' 'Ret' 'Cam' 'Men' 'Tau' 'Dor' 'Cae'
#  'Pic' 'Aur' 'Ori' 'Lep' 'Col' 'Mon' 'Gem' 'Car' 'Pup' 'CMa' 'Lyn' 'Vol'
#  'CMi' 'Cha' 'Cnc' 'Vel' 'UMa' 'Hya' 'Pyx' 'Leo' 'LMi' 'Dra' 'Ant' 'Sex'
#  'Crt' 'Cen' 'Mus' 'Vir' 'Cru' 'Crv' 'Com' 'CVn' 'Boo' 'Cir' 'Aps' 'Lup'
#  'Lib' 'TrA' 'Ser' 'Nor' 'CrB' 'Sco' 'Her' 'Oph' 'Ara' 'Pav' 'Sgr' 'CrA'
#  'Tel' 'Lyr' 'Sct' 'Aql' 'Sge' 'Vul' 'Cyg' 'Cap' 'Del' 'Mic' 'Ind' 'Aqr'
#  'Equ' 'PsA' 'Gru' 'Lac']

# %%
constellation = "Ori"

stars = df[df["con"] == constellation]

print(stars[["id", "proper", "ra", "dec", "mag", "con"]])
# Out:
#             id proper        ra        dec    mag  con
# 21952    21952    NaN  4.730327   3.477886   8.20  Ori
# 21968    21968    NaN  4.734367  12.991348   7.61  Ori
# 21991    21991    NaN  4.740508  11.146137   5.39  Ori
# 22008    22008    NaN  4.745037   0.568101   7.22  Ori
# 22010    22010    NaN  4.745762  14.626802   8.08  Ori
# ...        ...    ...       ...        ...    ...  ...
# 118405  118413    NaN  6.072574  18.696475   7.98  Ori
# 118409  118417    NaN  6.181965  10.320000  12.50  Ori
# 118412  118420    NaN  6.286339   5.119493  13.42  Ori
# 118416  118424    NaN  6.346740   6.755984  16.37  Ori
# 119602  119619    NaN  5.225917  -8.147778   6.37  Ori
#
# [1977 rows x 6 columns]

# %%
# 값 테스트용.
import pandas as pd

from astropy.coordinates import SkyCoord, EarthLocation, AltAz
from astropy.time import Time
import astropy.units as u


# CSV 불러오기
df = pd.read_csv("data/hyg/current/hyg_v44.csv.gz")


# 오리온자리 별만 추출
stars = df[
    (df["con"] == "Ori") &
    (df["ra"].notna()) &
    (df["dec"].notna())
]


# 첫 번째 별 선택
star = stars.iloc[0]

ra = star["ra"]
dec = star["dec"]


# 별의 적경 / 적위
star_coord = SkyCoord(
    ra=ra * u.deg,
    dec=dec * u.deg,
    frame="icrs"
)


# 관측 위치: 서울
location = EarthLocation(
    lat=37.5665 * u.deg,
    lon=126.9780 * u.deg,
    height=38 * u.m
)


# 현재 시간
time = Time.now()


# 관측 좌표계
altaz_frame = AltAz(
    obstime=time,
    location=location
)


# 적경/적위를 현재 하늘의 고도/방위각으로 변환
altaz = star_coord.transform_to(altaz_frame)


# 결과 출력
print("========== Astropy 테스트 ==========")
print("별자리 :", star["con"])
print("ID     :", star["id"])
print("RA     :", ra, "도")
print("Dec    :", dec, "도")
print("Mag    :", star["mag"])
print()
print("현재 고도(Altitude):", altaz.alt.deg, "도")
print("현재 방위각(Azimuth):", altaz.az.deg, "도")
# Out:
# ========== Astropy 테스트 ==========
# 별자리 : Ori
# ID     : 21952
# RA     : 4.730327 도
# Dec    : 3.477886 도
# Mag    : 8.2
#
# 현재 고도(Altitude): -44.45021469966426 도
# 현재 방위각(Azimuth): 29.956166207084262 도
